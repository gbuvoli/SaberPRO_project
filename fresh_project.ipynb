# %%
import pandas as pd
import numpy as np

# %%
#Vamos a cruzar los datasets

# %%
url="Saber_Pro_20241022.csv"
pob = pd.read_csv(url)
url ='dataforeda.csv'
sam_clean=pd.read_csv(url)
print(sam_clean.columns)
# Out:
# Index(['Documento', 'COMPETENCIAS CIUDADANAS', 'COMUNICACIÓN ESCRITA',
#        'INGLÉS', 'LECTURA CRÍTICA', 'RAZONAMIENTO CUANTITATIVO', 'Periodo',
#        'Aplicacion', 'Examen', 'Tipo_Documento', 'Nombre', 'Numero_Registro',
#        'Tipo_Evaluado', 'SNIES_Programa', 'Programa', 'Ciudad', 'ID_NBC',
#        'NBC', 'PG', 'Perc_Global', 'Perc_NBC', 'Nivel_Desempeño', 'Perc_Mod',
#        'Perc_nbc_mod', 'ID', 'SABER11', 'Creditos_Totales_Cursados_PR',
#        'CRED_APROBADOS_TOTALES', 'Promedio_PR', 'Puntos_Totales_PR',
#        'Periodo_Matricula'],
#       dtype='object')

# %%
pob.rename(columns={'ESTU_CONSECUTIVO':'Numero_Registro'}, inplace=True)

# %%
#Checkeamos los tamaños 
print(pob.shape,
sam_clean.shape)
# Out:
# (1217482, 57) (4615, 31)

# %%
pob[pob['INST_COD_INSTITUCION']==1713.0]
# Out:
#          PERIODO Numero_Registro  ... MOD_INGLES_PUNT MOD_COMPETEN_CIUDADA_PUNT
# 116        20183  EK201830127621  ...           190.0                       186
# 446        20183  EK201830114366  ...           194.0                       131
# 703        20183  EK201830218440  ...           222.0                       173
# 982        20195  EK201950214616  ...           202.0                       163
# 1038       20195  EK201950119915  ...           203.0                       162
# ...          ...             ...  ...             ...                       ...
# 1207568    20222  EK202220216934  ...           300.0                       180
# 1209195    20222  EK202220184259  ...           300.0                       191
# 1211528    20222  EK202220206113  ...           189.0                       189
# 1215007    20222  EK202220201484  ...           219.0                       164
# 1216390    20222  EK202220166281  ...           215.0                       168
#
# ...

# %%
sam_clean.sample(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sam_clean.sample(10)
#
# NameError: name 'sam_clean' is not defined

# %%
pob['PERIODO'].max()
# Out:
# 20226

# %%
pob[pob['Numero_Registro']=='EK202123186673']
# Out:
# Empty DataFrame
# ...

# %%
import pandas as pd

# Supongamos que ya tienes tus DataFrames definidos
# por ejemplo:
# pob = pd.DataFrame({'Numero_Registro': [1, 2, 3, 4]})
# sam_clean = pd.DataFrame({'Numero_Registro': [3, 4, 5, 6]})

# Encuentra los registros en común
comunes = sam_clean['Numero_Registro'][sam_clean['Numero_Registro'].isin(pob['Numero_Registro'])]

# Contar cuántos hay
cantidad_comunes = comunes.count()

# Mostrar el resultado
print(f'Cantidad de valores en común: {cantidad_comunes}')
# Out:
# Cantidad de valores en común: 395

# %%
pob[pob['Numero_Registro'].isin(sam_clean['Numero_Registro'])]
# Out:
#          PERIODO Numero_Registro  ... MOD_INGLES_PUNT MOD_COMPETEN_CIUDADA_PUNT
# 2875       20225  EK202250196188  ...           205.0                       100
# 3163       20212  EK202120283853  ...           173.0                       103
# 3547       20212  EK202120094987  ...           178.0                       169
# 6790       20212  EK202120268185  ...           196.0                       152
# 6982       20212  EK202120127845  ...           143.0                       147
# ...          ...             ...  ...             ...                       ...
# 1138500    20222  EK202220153932  ...           123.0                       149
# 1165111    20222  EK202220220061  ...           187.0                       151
# 1174982    20222  EK202220196741  ...           157.0                       159
# 1176256    20222  EK202220112854  ...           153.0                       132
# 1178519    20222  EK202220160648  ...           162.0                       194
#
# ...
